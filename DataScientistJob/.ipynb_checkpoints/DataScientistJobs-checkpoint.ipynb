# %% [markdown]
# # Would you become a data scientist?
# # Let's explore skills required and salary expectations from some job listings!
#
# ## by Mariangela Bonghi
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling and cleaning</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# I started studying in the fascinating world of data one year ago. The more I learn, the more I found to learn. If you want to become a data scientist, you can find yourself overwhelmed by the number of tools and concepts and you maybe wondering what are the most required skills or what is the salary expectation or what kind of industry has the higher demands for data scientists.
# I have found on [Kaggle](https://www.kaggle.com/andrewmvd/data-scientist-jobs) a very interesting dataset created by [picklesueat](https://github.com/picklesueat/data_jobs_data) that contains more than 3900 job listing for data scientist positions, with features such as:
#
# - Salary Estimate
# - Location
# - Company Rating
# - Job Description
# - and more.
#
# The data were collected around 7/8/2020
#
# So, let's start this investigation and try to answer the following questions:
# - What are the most required skills?
# - What are the locations with the higher demands for data scientist?
# - What are the industries with the higher demands for data scientists?
# - What is the salary expectation?

# %% [markdown]
# ### Import statements for the packages that are going to be used

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling and Cleaning
# In this section we load the data and see the general structure of the dataset. If necessary, we will take some actions on the data in order to prepare them for the analysis.
#
#
# ### General Properties

# %%
# Read dataset
df=pd.read_csv('DataScientist.csv')
df.head(1)
# Out:
#    Unnamed: 0  index              Job Title               Salary Estimate  \
# 0           0      0  Senior Data Scientist  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating Company Name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5  Hopper\n3.5
#
#        Location      Headquarters                   Size  Founded  \
# 0  New York, NY  Montreal, Canada  501 to 1000 employees     2007
#
#    Type of ownership         Industry            Sector  \
# 0  Company - Private  Travel Agencies  Travel & Tourism
#
#                     Revenue Competitors Easy Apply
# 0  Unknown / Non-Applicable          -1         -1

# %%
#number of samples and number of columns
df.shape
# Out:
# (3909, 17)

# %%
#check for duplicated columns in the dataset: there are no duplicates in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
#General information about data: there are no missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3909 non-null   int64
#  1   index              3909 non-null   int64
#  2   Job Title          3909 non-null   object
#  3   Salary Estimate    3909 non-null   object
#  4   Job Description    3909 non-null   object
#  5   Rating             3909 non-null   float64
#  6   Company Name       3909 non-null   object
#  7   Location           3909 non-null   object
#  8   Headquarters       3909 non-null   object
#  9   Size               3909 non-null   object
#  10  Founded            3909 non-null   int64
#  11  Type of ownership  3909 non-null   object
#  12  Industry           3909 non-null   object
#  13  Sector             3909 non-null   object
#  14  Revenue            3909 non-null   object
#  15  Competitors        3909 non-null   object
# ...

# %% [markdown]
# In the dataset there are 17 columns and 3909 rows and there are no duplicate rows.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'Easy Apply'],
#       dtype='object')

# %% [markdown]
# We make a copy of the dataset and drop all the columns that we are not going to use. For the remaining columns, we rename them removing spaces and using lowercase.

# %%
#Copy of the dataset
df_copy=df

# %%
#Put in lower case all the column names
df_copy.columns=df_copy.columns.str.lower()

# %%
df_copy.columns
# Out:
# Index(['unnamed: 0', 'index', 'job title', 'salary estimate',
#        'job description', 'rating', 'company name', 'location', 'headquarters',
#        'size', 'founded', 'type of ownership', 'industry', 'sector', 'revenue',
#        'competitors', 'easy apply'],
#       dtype='object')

# %%
#drop the columns that we are not going to use
df_copy.drop(['unnamed: 0','index','job title','company name','headquarters','founded','type of ownership',
              'sector','competitors','easy apply'], axis=1, inplace=True)

# %%
# Removing spaces from column name "salary estimate" and "job description"
df_copy = df_copy.rename(columns={'salary estimate': 'salary_estimate'});
df_copy = df_copy.rename(columns={'job description': 'job_description'});

# %%
#datatypes of columns
df_copy.dtypes
# Out:
# salary_estimate     object
# job_description     object
# rating             float64
# location            object
# size                object
# industry            object
# revenue             object
# dtype: object

# %%
#datatypes of "object" columns
type(df_copy['salary_estimate'][0]),\
type(df_copy['job_description'][0]),\
type(df_copy['location'][0]),\
type(df_copy['size'][0]),\
type(df_copy['industry'][0]),\
type(df_copy['revenue'][0])
# Out:
# (str, str, str, str, str, str)

# %% [markdown]
# We don't take any actions on data types

# %% [markdown]
# ### Cleaning "salary_estimate" column

# %%
#exploring values in the column
df_copy['salary_estimate'].value_counts()
# Out:
# $93K-$151K (Glassdoor est.)         62
# $113K-$180K (Glassdoor est.)        61
# $71K-$122K (Glassdoor est.)         60
# $111K-$175K (Glassdoor est.)        60
# $119K-$147K (Glassdoor est.)        44
#                                     ..
# $114K-$185K (Glassdoor est.)         7
# $99K-$173K (Glassdoor est.)          6
# $10-$26 Per Hour(Glassdoor est.)     3
# $146K-$175K (Glassdoor est.)         3
# $41K-$74K (Glassdoor est.)           1
# Name: salary_estimate, Length: 148, dtype: int64

# %% [markdown]
# In the above cell we can see the general structure of this column. Let's clean this data adding two more columns: the minimum salary and the maximum salary. In order to do this, we split the values in two columns and we remove the characters leaving only the numeric values. The salaries are expressend most of the times as annual salary but in some cases there is the salary per hour: let's transform this data in an annual salary, assuming that we work 8 hours per days, 20 days per month and 12 months per year.

# %%
#Find all the rows that contains salary per hour
df_copy[df_copy['salary_estimate'].str.contains("Hour")].salary_estimate.value_counts()
# Out:
# $17-$27 Per Hour(Glassdoor est.)    11
# $34-$53 Per Hour(Glassdoor est.)     7
# $10-$26 Per Hour(Glassdoor est.)     3
# Name: salary_estimate, dtype: int64

# %% [markdown]
# We can see that there are three cases in which the salary is expressed per hour.
# - For the first case:
# 17 * 8hours * 20days * 12months = 32640
# 27 * 8hours * 20days * 12months = 51840
# > We replace "$17-$27 Per Hour(Glassdoor est.)" with "$32640-$51840"
# - For the second case:
# 34 * 8hours * 20days * 12months = 65280
# 53 * 8hours * 20days * 12months = 101760
# >  We replace "$34-$53 Per Hour(Glassdoor est.)" with "$65280-$101760"
# - For the third case:
# 10 * 8hours * 20days * 12months = 19200
# 26 * 8hours * 20days * 12months = 49920
# >  We replace "$10-$26 Per Hour(Glassdoor est.)" with "$19200-$49920"

# %%
#Replace statements for the cases above:
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('$17-$27 Per Hour(Glassdoor est.)','32640-51840',regex=False);
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('$34-$53 Per Hour(Glassdoor est.)','65280-101760',regex=False);
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('$10-$26 Per Hour(Glassdoor est.)','19200-49920',regex=False)

# %% [markdown]
# Exploring the dataset with excel, we can notice that the majority of the rows contains the string '(Glassdoor est.)', but there are also rows that contain the string "(Employer est.)":

# %%
#Replace statemants for the string "(Employer est.)"
df_copy[df_copy['salary_estimate'].str.contains("(Employer est.)")].salary_estimate.value_counts()
# Out:
# /Users/Arirammstein/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# $82K-$129K(Employer est.)     30
# $200K-$250K(Employer est.)    29
# Name: salary_estimate, dtype: int64

# %% [markdown]
# Now we can remove all the string values in order to have only numerical ones:

# %%
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('(Glassdoor est.)','',regex=False);
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('$','',regex=False);
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('K','000',regex=False);
df_copy['salary_estimate'] = df_copy['salary_estimate'].str.replace('(Employer est.)','',regex=False);

# %% [markdown]
# Finally, we can split the column in two different columns and drop the original one:

# %%
df_copy[['salary_min','salary_max']] = df_copy.salary_estimate.str.split("-",expand=True,)

# %%
df_copy.drop(['salary_estimate'], axis=1, inplace=True)

# %%
# convert the new two columns as numeric
df_copy[["salary_min", "salary_max"]] = df_copy[["salary_min", "salary_max"]].apply(pd.to_numeric)

# %% [markdown]
# ### Extracting skills from "job_description" column

# %% [markdown]
# From the job_description column we extract some of the required skills and create a new column for each one. First we trasform in upper case all the rows of the column, then we'll look for the following skills: Looker, Tableau, SQL, Python, R, Excel, Julia, Scala, Matlab and degree

# %%
# Upper case for all the rows of job description column
df_copy['job_description'] = df_copy['job_description'].str.upper()

# %% [markdown]
# In case of R language, we can see in the dataset that we can find "R" with the following string " R ", " R,", "/R","R/","(R","R)": we replace all of these with "ERRE"

# %%
df_copy['job_description'] = df_copy['job_description'].str.replace(' R,','ERRE',regex=False);
df_copy['job_description'] = df_copy['job_description'].str.replace(' R ','ERRE',regex=False);
df_copy['job_description'] = df_copy['job_description'].str.replace('/R','ERRE',regex=False);
df_copy['job_description'] = df_copy['job_description'].str.replace('R/','ERRE',regex=False);
df_copy['job_description'] = df_copy['job_description'].str.replace('(R','ERRE',regex=False);
df_copy['job_description'] = df_copy['job_description'].str.replace('R)','ERRE',regex=False);

# %%
skill =['LOOKER','TABLEAU','SQL','PYTHON','EXCEL','JULIA','SCALA','MATLAB','DEGREE']

# %% [markdown]
# For all the skills listed above, we create a column with the following values: 1 if the job description contains the skill, 0 if the job description doesn't contain the skill.

# %%
for s in skill:
    df_copy[s] = df_copy['job_description'].map(lambda x: 1 if s in str(x) else 0);
df_copy['R'] = df_copy['job_description'].map(lambda x: 1 if 'ERRE'  in str(x) else 0);

# %% [markdown]
# ### Cleaning "location" column

# %%
df_copy['location'].head(5)
# Out:
# 0     New York, NY
# 1     New York, NY
# 2     New York, NY
# 3    Lyndhurst, NJ
# 4     New York, NY
# Name: location, dtype: object

# %% [markdown]
# In the location column there are the city and the state divided by ",". We will remove the city and leave only the state.

# %%
# Split the city and the state in two colums
df_copy[['to_drop','location']] = df_copy.location.str.split(",",expand=True,)

# %%
#Remove the column with the city
df_copy.drop(['to_drop'], axis=1, inplace=True)

# %%
df_copy.location.value_counts()
# Out:
#  TX                1253
#  CA                1069
#  IL                 363
#  PA                 324
#  NY                 313
#  AZ                 295
#  OH                 177
#  FL                  69
#  NJ                  32
#  DE                  10
#  United Kingdom       4
# Name: location, dtype: int64

# %% [markdown]
# We replace the state code with the full name:

# %%
df_copy['location'] = df_copy['location'].str.replace('TX','Texas',regex=False);
df_copy['location'] = df_copy['location'].str.replace('CA','California',regex=False);
df_copy['location'] = df_copy['location'].str.replace('IL','Illinois',regex=False);
df_copy['location'] = df_copy['location'].str.replace('PA','Pennsylvania',regex=False);
df_copy['location'] = df_copy['location'].str.replace('NY','New York',regex=False);
df_copy['location'] = df_copy['location'].str.replace('AZ','Arizona',regex=False);
df_copy['location'] = df_copy['location'].str.replace('OH','Ohio',regex=False);
df_copy['location'] = df_copy['location'].str.replace('FL','Florida',regex=False);
df_copy['location'] = df_copy['location'].str.replace('NJ','New Jersey',regex=False);
df_copy['location'] = df_copy['location'].str.replace('DE','Delaware',regex=False);

# %% [markdown]
# ### Cleaning the "size" column

# %%
df_copy['size'].value_counts()
# Out:
# 10000+ employees           993
# 51 to 200 employees        563
# 1001 to 5000 employees     553
# 1 to 50 employees          550
# 201 to 500 employees       418
# 501 to 1000 employees      307
# -1                         229
# 5001 to 10000 employees    219
# Unknown                     77
# Name: size, dtype: int64

# %% [markdown]
# From the above list we see a "-1" value. We assume that in those cases the size of the company is unknown:

# %%
df_copy['size'] = df_copy['size'].str.replace('-1','Unknown',regex=False);

# %% [markdown]
# ### Cleaning "revenue" column

# %%
df_copy['revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            1163
# $10+ billion (USD)                   599
# $100 to $500 million (USD)           338
# -1                                   229
# $50 to $100 million (USD)            214
# $2 to $5 billion (USD)               211
# $10 to $25 million (USD)             191
# $1 to $2 billion (USD)               180
# $1 to $5 million (USD)               170
# $25 to $50 million (USD)             143
# $5 to $10 billion (USD)              133
# Less than $1 million (USD)           124
# $500 million to $1 billion (USD)     114
# $5 to $10 million (USD)              100
# Name: revenue, dtype: int64

# %% [markdown]
# From the above list we see also a "-1" value. We assume that in those cases the revenue of the company is unknown:

# %%
df_copy['revenue'] = df_copy['revenue'].str.replace('-1','Unknown / Non-Applicable',regex=False);

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory data analysis

# %% [markdown]
# ### What is the salary expectation?

# %% [markdown]
# As you can see in the cells below, the minimum salary goes from 12000 to 200000 USD per year, with a mean of around 82000 USD per year; The maximum salary goes from around 50000 to 254000 USD per year, with a mean of 134000 USD per year:

# %%
df_copy['salary_min'].describe()
# Out:
# count      3909.000000
# mean      82017.549245
# std       34170.454215
# min       12000.000000
# 25%       52000.000000
# 50%       76000.000000
# 75%      110000.000000
# max      200000.000000
# Name: salary_min, dtype: float64

# %%
df_copy['salary_max'].describe()
# Out:
# count      3909.000000
# mean     134000.593502
# std       44714.639348
# min       49920.000000
# 25%       97000.000000
# 50%      129000.000000
# 75%      165000.000000
# max      254000.000000
# Name: salary_max, dtype: float64

# %% [markdown]
# Let's take a closer look at the minimum salary and the maximum salary:

# %%
num_bins= 10
plt.hist(df_copy['salary_min'], num_bins, label='minimum salary', alpha=0.5);
plt.hist(df_copy['salary_max'], num_bins, label='maximum salary', alpha=0.5);
plt.legend(loc='upper right')
plt.title("Minimum and Maximum salary in the job listings")
plt.xlabel("Salary")
plt.ylabel("Job Listings count")
plt.show()

# %% [markdown]
# The curves are both skewed to the left and have more or less the same trend.

# %% [markdown]
# We explore now the relation between salary and company ratings

# %%
df_rating = df_copy[df_copy['rating']!=-1]
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.hist2d(data=df_rating,x='rating',y='salary_min',cmin=0.5,cmap='viridis_r')
plt.colorbar()
plt.title('Minimum Salary vs Company Rating')
plt.xlabel('Rating')
plt.ylabel('Minimum Salary');


plt.subplot(1, 2, 2)
plt.hist2d(data=df_rating,x='rating',y='salary_max',cmin=0.5,cmap='viridis_r')
plt.colorbar()
plt.title('Maximum Salary vs Company Rating')
plt.xlabel('Rating')
plt.ylabel('Maximum Salary');
#to avoid overlap between graphs
plt.tight_layout()
plt.show();

# %% [markdown]
# Company ratings are generally determined by recent employee feedback. If we observe the rating between 3.5 and 4, apparently it seems that higher is the rating the higher the salary expectations. However, companies with a rating of 5, don't have the maximum salary expectations at all. This could lead us to think that money is not all that matters.

# %% [markdown]
# We explore now the relation between salary and company size

# %%
df_size = df_copy[df_copy['size']!='Unknown']
x_axis_values=['1 to 50 employees','51 to 200 employees','201 to 500 employees','501 to 1000 employees',
            '1001 to 5000 employees','5001 to 10000 employees', '10000+ employees']

plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.scatter(df_size['size'], df_size['salary_min'], c=df_size['salary_min'], cmap='Spectral')
plt.colorbar()
plt.title('Minimum salary vs Company size')
plt.xlabel('Company size')
plt.ylabel('Minimum salary')
plt.xticks(ticks=range(len(x_axis_values)), labels=x_axis_values, rotation=45)

plt.subplot(1, 2, 2)
plt.scatter(df_size['size'], df_size['salary_max'], c=df_size['salary_max'], cmap='Spectral')
plt.colorbar()
plt.title('Maximum salary vs Company size')
plt.xlabel('Company size')
plt.ylabel('Maximum salary')
plt.xticks(ticks=range(len(x_axis_values)), labels=x_axis_values, rotation=45)

plt.show()

# %% [markdown]
# Salary expectation seems not to be related to the company size.

# %% [markdown]
# We explore now the relation between salary and company revenue.

# %%
df_revenue = df_copy[df_copy['revenue']!='Unknown / Non-Applicable']
x_axis_values=['Less than $1 million (USD)','$1 to $5 million (USD)',
            '$5 to $10 million (USD)','$10 to $25 million (USD)','$25 to $50 million (USD)',
            '$50 to $100 million (USD)','$100 to $500 million (USD)','$500 million to $1 billion (USD)',
            '$1 to $2 billion (USD)','$2 to $5 billion (USD)','$5 to $10 billion (USD)','$10+ billion (USD)']
f, ax = plt.subplots(1, 2, figsize=(15, 8), sharex=True)

g=sns.boxplot(x="revenue", y="salary_min", data=df_revenue, order=x_axis_values,ax=ax[0])
g.axhline(y = 82017.549245, color = 'g', linestyle = '--',label='mean minimum salary')
g.legend(loc='upper right',fontsize=15)
g.set_title('Minimum salary vs Company size',fontsize=20)
g.set_xlabel('Company revenue',fontsize=15)
g.set_ylabel('Minimum salary',fontsize=15)
g.set_xticklabels(g.get_xticklabels(),rotation=45)


g=sns.boxplot(x="revenue", y="salary_max", data=df_revenue, order=x_axis_values,ax=ax[1])
g.axhline(y = 134000.593502, color = 'g', linestyle = '--',label='mean maximum salary')
g.legend(loc='upper right',fontsize=15)
g.set_title('Maximum salary vs Company size',fontsize=20)
g.set_xlabel('Company revenue',fontsize=15)
g.set_ylabel('Maximum salary',fontsize=15)
g.set_xticklabels(g.get_xticklabels(),rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# For companies that have a revenue from 5 billion (USD) and above, the mean of the minimum and maximum salary are above the mean. It's interesting to notice that also the companies with revenue from 1 to 5 million (USD) have a salary above the mean. If we take a closer look to these companies we can see that they have also a mean rating of 3.77 where we have observed high mean salaries:

# %%
#Take a closer look to those companies that have a revenue from 1 to 5 million (USD)
revenue_to_keep =['$1 to $5 million (USD)']
revenue_df = df_copy[df_copy.revenue.isin(revenue_to_keep)]
revenue_df=revenue_df[revenue_df['rating']!=-1]
round(revenue_df.rating.mean(),2)
# Out:
# 3.77

# %% [markdown]
# ### What are the locations with the higher demands for data scientist?

# %% [markdown]
# The dataset contains job listings from different states of United State, apart for 4 job listings that are from the United Kingdom.

# %%
df_location=df_copy.location.value_counts()

# %%
color_graph=sns.color_palette()[9]
sns.barplot(x=df_location, y=df_location.index.values,color=color_graph)
plt.xticks(rotation=90) 
plt.title('Location',fontsize=18)
plt.xlabel('Job Posting count',fontsize=18);

# %% [markdown]
# From the above graph, Texas and California are the states with the majority of requests of data scientist. Before moving there, let's take a look at the salary expectations among all locations.

# %%
plt.subplots(figsize=(15, 6))
plt.subplot(1, 2, 1)

df_copy.groupby('location').mean()['salary_min'].plot(kind='bar')
plt.axhline(y = 82017.549245, color = 'g', linestyle = '--',label='mean minimum salary')
plt.legend(loc='upper right',fontsize=10)
plt.ylabel('Minimum Salary', fontsize=12)
plt.xticks(rotation=45)
plt.title('Minimum Salary vs Location',fontsize=18)

plt.subplot(1, 2, 2)

df_copy.groupby('location').mean()['salary_max'].plot(kind='bar')
plt.axhline(y = 134000.593502, color = 'g', linestyle = '--',label='mean maximum salary')
plt.legend(loc='upper right',fontsize=10)
plt.ylabel('Maximum Salary', fontsize=12)
plt.xticks(rotation=45)
plt.title('Maximum Salary vs Location',fontsize=18)

plt.tight_layout()
plt.show()

# %% [markdown]
# From the above graph: California, Delaware, New York and New Jersey have a mean of minimum and maximum salary greater than the mean of minimum salary and maximum salary of all the locations.

# %% [markdown]
# ### What are the industries with the higher demands for data scientists?

# %% [markdown]
# Here below we explore the top 10 industries requiring data scientists

# %%
df_copy[df_copy['industry']!='-1']['industry'].value_counts()[:10].plot.barh()
plt.title('Top 10 industries requiring data scientists');

# %%
#We create a new dataset "new_df" containing the job listings for the top 10 industries in order to take
# a look at the salaries
industries_to_keep =['IT Services','Staffing & Outsourcing','Biotech & Pharmaceuticals',
                    'Computer Hardware & Software','Internet','Health Care Services & Hospitals',
                    'Consulting','Enterprise Software & Network Solutions','Investment Banking & Asset Management',
                    'Advertising & Marketing']
new_df = df_copy[df_copy.industry.isin(industries_to_keep)]

# %%
f, ax = plt.subplots(1, 2, figsize=(15, 10), sharex=True)

g=sns.boxplot(x="industry", y="salary_min", data=new_df,ax=ax[0],order=industries_to_keep)
g.axhline(y = 82017.549245, color = 'g', linestyle = '--',label='mean minimum salary')
g.legend(loc='upper right',fontsize=10)
g.set_ylabel('Minimum Salary', fontsize=14)
g.set_xlabel('Top 10 Industries', fontsize=14)
g.set_xticklabels(g.get_xticklabels(),rotation=40, ha="right")
g.set_title('Minimum salary vs Top 10 Industries requiring data scientists',fontsize=15)

g=sns.boxplot(x="industry", y="salary_max", data=new_df,ax=ax[1],order=industries_to_keep)
g.axhline(y = 134000.593502, color = 'g', linestyle = '--',label='mean maximum salary')
g.legend(loc='upper right',fontsize=10)
g.set_ylabel('Maximum Salary', fontsize=14)
g.set_xlabel('Top 10 Industries', fontsize=14)
g.set_xticklabels(g.get_xticklabels(),rotation=40, ha="right")
g.set_title('Maximum salary vs Top 10 Industries requiring data scientists',fontsize=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# The top 10 industries requiring data scientist are: 'IT Services', 'Staffing & Outsourcing', 'Biotech & Pharmaceuticals', 'Computer Hardware & Software', 'Internet', 'Health Care Services & Hospitals', 'Consulting', 'Enterprise Software & Network Solutions', 'Investment Banking & Asset Management', 'Advertising & Marketing'. The mean of the minimum and maximum salaries are above the mean for the following industries: 'Computer Hardware & Software', 'Internet', 'Advertising & Marketing', 'Enterprise Software & Network Solutions'

# %% [markdown]
# ### What are the most required skills?

# %%
skill =['LOOKER','TABLEAU','SQL','PYTHON','EXCEL','JULIA','SCALA','MATLAB','DEGREE','R']

# %%
skill_counts = df_copy[skill].sum()
print(skill_counts)
# Out:
# LOOKER       78
# TABLEAU     673
# SQL        2022
# PYTHON     2057
# EXCEL      1855
# JULIA        20
# SCALA       877
# MATLAB      197
# DEGREE     2252
# R          2710
# dtype: int64

# %%
skill_counts.index.values
# Out:
# array(['LOOKER', 'TABLEAU', 'SQL', 'PYTHON', 'EXCEL', 'JULIA', 'SCALA',
#        'MATLAB', 'DEGREE', 'R'], dtype=object)

# %%
color_graph=sns.color_palette()[9]
order_list =['R','DEGREE','PYTHON','SQL','EXCEL','SCALA','TABLEAU','MATLAB','LOOKER','JULIA']
sns.barplot(x=skill_counts.index.values, y=skill_counts,color=color_graph,order=order_list)
plt.xticks(rotation=90) 
plt.title('Requested Skills',fontsize=18)
plt.ylabel('Job Listings count',fontsize=18);

# %% [markdown]
# From the above graph:  R is very popular followed by Python, SQL and Excel. It's interesting to note that the degree is often mentioned as an additional skill.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# Let's recap!
# - The minimum salary goes from 12000 to 200000 USD per year, with a mean of around 82000 USD per year; The maximum salary goes from around 50000 to 254000 USD per year, with a mean of 134000 USD per year;
# - Company ratings are generally determined by recent employee feedback. If we observe the rating between 3.5 and 4, apparently it seems that higher is the rating the higher the salary expectations. However, companies with a rating of 5, don't have the maximum salary expectations at all. This could lead us to think that money is not all that matters;
# - Salary expectation seems not to be related to the company size;
# - For companies that have a revenue from 5 billion (USD) and above, the mean of the minimum and maximum salary are above the mean. It's interesting to notice that also the companies with revenue from 1 to 5 million (USD) have a salary above the mean. If we take a closer look to these companies we can see that they have also a mean rating of 3.77 where we have observed high mean salaries;
# - Texas and California are the states with the majority of requests of data scientist. California, Delaware, New York and New Jersey have a mean of minimum and maximum salary greater than the mean of minimum salary and maximum salary of all the locations;
# - The top 10 industries requiring data scientist are: 'IT Services', 'Staffing & Outsourcing', 'Biotech & Pharmaceuticals', 'Computer Hardware & Software', 'Internet', 'Health Care Services & Hospitals', 'Consulting', 'Enterprise Software & Network Solutions', 'Investment Banking & Asset Management', 'Advertising & Marketing'. The mean of the minimum and maximum salaries are above the mean for the following industries: 'Computer Hardware & Software', 'Internet', 'Advertising & Marketing', 'Enterprise Software & Network Solutions';
# - R is very popular followed by Python, SQL and Excel. It's interesting to note that the degree is often mentioned as an additional skill.
